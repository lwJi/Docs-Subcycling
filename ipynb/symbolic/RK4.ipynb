# %%
Series[Exp[x], {x, 0, 10}]
# Out:
#          2    3    4    5     6      7      8        9        10
#         x    x    x    x     x      x      x        x        x           11
# 1 + x + -- + -- + -- + --- + --- + ---- + ----- + ------ + ------- + O[x]
#         2    6    24   120   720   5040   40320   362880   3628800
